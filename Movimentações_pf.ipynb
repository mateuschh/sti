# %% [markdown]
# <a href="https://colab.research.google.com/github/mateuschh/sti/blob/main/Movimenta%C3%A7%C3%B5es_pf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sklearn
import pandas as pd
import matplotlib.pyplot as plt

# %%
pf = 'sti_movemento.csv'

# Carregar o arquivo CSV em um DataFrame do pandas
df = pd.read_csv(pf)

# %%
df
# Out:
#         Unnamed: 0  UF     Tipo Classificacao  \
# 0                0  AC  Entrada    Permanente
# 1                1  AC  Entrada    Permanente
# 2                2  AC  Entrada    Permanente
# 3                3  AC  Entrada    Permanente
# 4                4  AC  Entrada    Visitante
# ...            ...  ..      ...           ...
# 230542        9425  SP  Saida      Temporário
# 230543        9426  SP  Saida      Temporário
# 230544        9427  SP  Saida      Temporário
# 230545        9428  SP  Saida      Temporário
# 230546        9429  SP  Saida      Outros
#
#                                    Nacionalidade  Pessoas        Data
# 0       Bolívia                                         9  01/01/2021
# 1       Haiti                                          18  01/01/2021
# 2       Peru                                            5  01/01/2021
# 3       Serra leoa                                      7  01/01/2021
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  UF     Tipo Classificacao  \
# 0           0  AC  Entrada    Permanente
# 1           1  AC  Entrada    Permanente
# 2           2  AC  Entrada    Permanente
# 3           3  AC  Entrada    Permanente
# 4           4  AC  Entrada    Visitante
#
#                               Nacionalidade  Pessoas        Data
# 0  Bolívia                                         9  01/01/2021
# 1  Haiti                                          18  01/01/2021
# 2  Peru                                            5  01/01/2021
# 3  Serra leoa                                      7  01/01/2021
# 4  Bolívia                                         2  01/01/2021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230547 entries, 0 to 230546
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     230547 non-null  int64
#  1   UF             230547 non-null  object
#  2   Tipo           230547 non-null  object
#  3   Classificacao  230547 non-null  object
#  4   Nacionalidade  230547 non-null  object
#  5   Pessoas        230547 non-null  int64
#  6   Data           230547 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 7.9+ MB

# %%
df["UF"].value_counts()
# Out:
# SP    71723
# RJ    35668
# PR    14889
# DF    13919
# RS    12189
# CE    10310
# BA     8921
# PE     8764
# MG     8206
# PA     6950
# SC     6737
# AM     6401
# MS     4345
# RN     3937
# AP     3853
# RR     3536
# AC     2928
# AL     1949
# MA     1297
# ES     1276
# RO     1076
# MT      712
# PB      464
# GO      258
# SE      237
# TO        2
# Name: UF, dtype: int64

# %%
df["Tipo"].value_counts()
# Out:
# Saida      116279
# Entrada    114268
# Name: Tipo, dtype: int64

# %%
df["Classificacao"].value_counts()
# Out:
# Outros        99731
# Visitante     86027
# Permanente    31251
# Temporário    13538
# Name: Classificacao, dtype: int64

# %%
df["Nacionalidade"].value_counts()
# Out:
# Argentina                                   5882
# Portugal                                    5793
# Estados unidos                              5438
# Itália                                      5437
# França                                      5421
#                                             ...
# Ilhas salomão                                  8
# Sudão do sul                                   7
# Nauru                                          3
# Micronésia                                     2
# Curaçao                                        2
# Name: Nacionalidade, Length: 209, dtype: int64

# %%
df["Pessoas"].value_counts()
# Out:
# 1         68731
# 2         30477
# 3         17245
# 4         12480
# 5          8975
#           ...
# 1421          1
# 8582          1
# 1929          1
# 8598          1
# 484136        1
# Name: Pessoas, Length: 3329, dtype: int64

# %%
df["Pessoas"].describe()
# Out:
# count    230547.000000
# mean        172.669738
# std        4980.296383
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%          15.000000
# max      484136.000000
# Name: Pessoas, dtype: float64

# %%
df["Data"].value_counts()
# Out:
# 01/03/2023    10078
# 01/12/2022    10025
# 01/04/2023     9824
# 01/01/2023     9603
# 01/11/2022     9520
# 01/05/2023     9464
# 01/07/2023     9430
# 01/06/2023     9254
# 01/02/2023     9071
# 01/10/2022     8732
# 01/07/2022     8620
# 01/08/2022     8471
# 01/09/2022     8404
# 01/04/2022     8155
# 01/06/2022     8149
# 01/05/2022     8141
# 01/03/2022     7516
# 01/12/2021     7204
# 01/01/2022     7124
# 01/11/2021     6824
# 01/02/2022     6704
# 01/10/2021     6123
# 01/09/2021     5553
# 01/08/2021     5478
# 01/07/2021     5330
# 01/01/2021     5255
# 01/06/2021     4829
# 01/05/2021     4723
# 01/04/2021     4480
# 01/03/2021     4330
# 01/02/2021     4133
# Name: Data, dtype: int64

# %%
df = df.drop("Unnamed: 0", axis=1)

# %%
df['UF'].value_counts().plot(kind='bar')
plt.title('Distribuição de UFs na Coluna')
plt.ylabel('Frequência')
plt.show()

# %%
UF_list = df['UF'].unique()

# %%
df['Tipo'].value_counts().plot(kind='bar')
plt.title('Distribuição de UFs na Coluna')
plt.ylabel('Frequência')
plt.show()

# %%
df['Classificacao'].value_counts().plot(kind='bar')
plt.title('Distribuição de UFs na Coluna')
plt.ylabel('Frequência')
plt.show()

# %%
df['Nacionalidade'].value_counts().plot(kind='bar')
plt.title('Distribuição de UFs na Coluna')
plt.ylabel('Frequência')
plt.show()

# %%
df['Data'].value_counts().plot(kind='bar')
plt.title('Distribuição de Datas')
plt.ylabel('Frequência')
plt.show()
